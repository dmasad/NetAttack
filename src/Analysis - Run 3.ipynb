# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
PATH = "/Users/dmasad/Dropbox/csss2013CoEv/Run 3 Data/"

# %%
attacker_cols = ["Generation", "ID", "Fitness"]
attacker_cols += ["Gene"+str(i) for i in range(1,8)]

# %%
defender_cols = ["Generation", "ID", "Fitness"]
defender_cols += ["Gene"+str(i) for i in range(1,11)]

# %%
attacker_data = pandas.read_csv(PATH + "attackers.csv", skiprows=1, names=attacker_cols)

# %%
defender_data = pandas.read_csv(PATH + "defenders.csv", skiprows=1, names=defender_cols)

# %% [markdown]
# ## Mean fitness

# %%
defender_mean = defender_data.groupby(by=["Generation"]).aggregate(np.mean)["Fitness"]
attacker_mean = attacker_data.groupby(by=["Generation"]).aggregate(np.mean)["Fitness"]

# %%
fitness_df = pandas.DataFrame({"Attacker": attacker_mean, "Defender": defender_mean})

# %%
fitness_df.plot()

# %% [markdown]
# # Gene means

# %%
attacker_genes = attacker_data.groupby(by=["Generation"]).aggregate(np.mean)

# %%
attacker_genes[attacker_genes.columns[2:]].plot()

# %%
attacker_genes[attacker_genes.columns[2:]].corr()
# Out:
#           Gene1     Gene2     Gene3     Gene4     Gene5     Gene6     Gene7
# Gene1  1.000000  0.431114 -0.772219  0.716453 -0.762909  0.555243 -0.251678
# Gene2  0.431114  1.000000 -0.385473  0.436205 -0.481087  0.156999  0.103219
# Gene3 -0.772219 -0.385473  1.000000 -0.563868  0.572901 -0.417071  0.127147
# Gene4  0.716453  0.436205 -0.563868  1.000000 -0.409802  0.704284 -0.151524
# Gene5 -0.762909 -0.481087  0.572901 -0.409802  1.000000 -0.168531  0.212589
# Gene6  0.555243  0.156999 -0.417071  0.704284 -0.168531  1.000000 -0.176912
# Gene7 -0.251678  0.103219  0.127147 -0.151524  0.212589 -0.176912  1.000000
